# %%
import networkx as nx
from pymatgen.core.structure import Structure
import os
os.chdir('/home/lucasperea/Documents/GithubRep/GraphMaterials/')
from GraphFunc.ZeoDataframeFunction import ZeoDataframe
from GraphFunc.ConexionFunction import Conexion
from pymatgen.io.cif import CifWriter
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from copy import deepcopy
import pickle

# %%
with open('../result/mat_df', 'rb') as handle:
    mat_df= pickle.load(handle)

# %%
    mat_df
# Out:
#      LargerNode  IndexLN  MostConnectedNodeCell  RadiusMCNC  \
# MVY     1.35952     38.0                   42.0     1.35952
# HEU     2.78640    185.0                  273.0     2.78640
# OSO     2.83700     76.0                   76.0     2.83700
# SAV     4.20836     14.0                   14.0     4.20836
# SFN     3.76763     11.0                   21.0     3.76763
# ..          ...      ...                    ...         ...
# UOZ     2.51394      0.0                  340.0     2.51394
# IWV     4.06994    112.0                   90.0     3.88259
# AEN     2.01689     12.0                   99.0     2.01689
# DOH     3.72721      0.0                   13.0     3.58520
# RUT     2.78055    120.0                  110.0     2.75504
#
#      MostConnectedNodeCellValue  MostConnectedAll  RadiusMCNA  \
# MVY                  502.679021            5459.0    0.830997
# HEU                  675.155733           11881.0    0.980197
# OSO                  334.343563            3558.0    2.770920
# SAV                 1369.153472              14.0    4.208360
# SFN                  814.063750           14003.0    0.452021
# ..                          ...               ...         ...
# UOZ                 1324.419122               0.0    2.513940
# IWV                 1032.134299           25154.0    0.771866
# AEN                  572.148545            4362.0    0.323528
# DOH                 1173.765383             857.0    0.402817
# RUT                  613.715341            3317.0    0.365440
#
#      MostConnectedAllValue
# MVY             503.205200
# HEU             677.023682
# OSO             336.214294
# SAV            1386.147949
# SFN             816.103821
# ..                     ...
# UOZ            1429.262451
# IWV            1034.600708
# AEN             573.375793
# DOH            1241.005371
# RUT             614.174255
#
# [202 rows x 8 columns]

# %%
vertex_table = vertex_table.append({'coord_x':vertex_table.loc[vertex_table['key']  == str(int(destination) + x_1), ['coord_x']].values[0][0], 'coord_y':vertex_table.loc[vertex_table['key']  == str(int(destination) + x_1), ['coord_y']].values[0][0], 'coord_z':vertex_table.loc[vertex_table['key']  == str(int(destination) + x_1), ['coord_z']].values[0][0],'min_dist_atom':vertex_table.loc[vertex_table['key']  == str(int(destination) + x_1),['min_dist_atom']].values[0][0],'key':str(int(destination) + x_1)},ignore_index = True)

# %%
path_nt2 = './Netwrk/EDI.nt2'
multiplier = [1,1,1]
box = np.array([6.926, 6.926, 6.410])

edge_table, vertex_table = ZeoDataframe(path_nt2, multiplier, box)
conexion = Conexion(vertex_table, edge_table)
# Out:
# DataFrame DONE

# %%
G = nx.MultiDiGraph()
G.add_edge(1, 2, **{'weight': 15, 'max': 3})
G.add_edge(1, 3, **{'weight': 30, 'max': 4})
G.add_edge(2, 3, **{'weight': 20, 'max': 3})
G.add_edge(2, 3, **{'weight': 20, 'max': 5})


def get_edge_weight(u, v):
    """Return the minimum weight of all edges between nodes u and v."""
    return min([e['weight'] for e in G.get_edge_data(u, v).values()])


def weighted_path_score(path):
    """Sum of edge weights in path."""
    edges = zip(path, path[1:])
    return sum(get_edge_weight(u, v) for u, v in edges)


paths = [tuple(p) for p in nx.all_simple_paths(G, 1, 1)]

# sort using the weighted path score
print(sorted(set(paths), key=weighted_path_score))
# Out:
# []

# %%
os.getcwd()
# Out:
# '/home/lucasperea/Documents/GithubRep/GraphMaterials'

# %%
# strc = Structure.from_file('../CifFiles/EDI.cif')

# %%
strc.make_supercell([2,2,1])

# %%
len(strc)
# Out:
# 240

# %%
# CifWriter(strc).write_file('../Netwrk/EDI.cif')

# %%
path_to_file = './Netwrk/EDI.nt2'

G = nx.Graph()
with open(path_to_file) as f:
    line = ' '

    while line:
        line = f.readline()

        if line == 'Vertex table:\n':
            
            while line:

                line = f.readline()
                
                if line == '\n':
                    break
                else:
                    line_list = line.split()
                    key = int(line_list[0])
#                     print(key)
                    coord_x = float(line_list[1])
                    coord_y = float(line_list[2])
                    coord_z = float(line_list[3])
                    min_dist_atom = float(line_list[4])
        
                    G.add_node(key, coord=np.array([coord_x, coord_y, coord_z]), rad_max_sph=min_dist_atom,
                              pagerank=1)

    #                 vertex_table = vertex_table.append({'coord_x':coord_x, 'coord_y':coord_y, 'coord_z':coord_z,
    #                                                     'min_dist_atom':min_dist_atom, 'key':key},ignore_index = True)


        x_1 = len(list(range(0,(sorted(list(G.nodes), reverse=True)[0] + 1))))
        
        
        
        if line == 'Edge table:\n':
            

            while line:

                line = f.readline()
                if line == '':
                    break
                line_list = line.split()
                origin = int(line_list[0])
                destination = int(line_list[2])
                larger_radius = float(line_list[3])
                x_sim = int(line_list[4])
                y_sim = int(line_list[5])
                z_sim = int(line_list[6])
                if x_sim == 1:
                    G.add_node(destination + x_1, coord=G.nodes[destination]['coord'] + np.array([box[0], 0, 0]),
                               rad_max_sph=G.nodes[destination]['rad_max_sph'], pagerank=1)
                    
                    G.add_edge(origin, destination + x_1, rad_max_sph=larger_radius)
                    print(destination + x_1)
                else:
                    if sum([abs(x_sim), abs(y_sim), abs(z_sim)]) == 0:
                        G.add_edge(origin, destination, rad_max_sph=larger_radius)
                        
                    else:
                        pass
                    
                
                
                
#                 if sum([abs(x_sim), abs(y_sim), abs(z_sim)]) == 0:
#                     pass
#                     edge_table = edge_table.append({'origin':origin, 'destination': destination, 'x_sim':x_sim,
#                                                     'y_sim':y_sim, 'z_sim':z_sim,'larger_radius':larger_radius},
#                                                    ignore_index = True)
                    #print('change')
# Out:
# 80
# 84
# 98
# 105
# 103
# 130
# 132
# 137
# 138
# 139

# %%
x = nx.draw(G, with_labels=True, font_weight='bold')
print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_27121/103261960.py in <module>
# ----> 1 x = nx.draw(G, with_labels=True, font_weight='bold')
#       2 print(x)
#
# ~/anaconda3/lib/python3.8/site-packages/networkx/drawing/nx_pylab.py in draw(G, pos, ax, **kwds)
#     121         kwds["with_labels"] = "labels" in kwds
#     122
# --> 123     draw_networkx(G, pos=pos, ax=ax, **kwds)
#     124     ax.set_axis_off()
#     125     plt.draw_if_interactive()
#
# ~/anaconda3/lib/python3.8/site-packages/networkx/drawing/nx_pylab.py in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     336     draw_networkx_edges(G, pos, arrows=arrows, **edge_kwds)
#     337     if with_labels:
# --> 338         draw_networkx_labels(G, pos, **label_kwds)
#     339     plt.draw_if_interactive()
#     340
#
# ~/anaconda3/lib/python3.8/site-packages/networkx/drawing/nx_pylab.py in draw_networkx_labels(G, pos, labels, font_size, font_color, font_family, font_weight, alpha, bbox, horizontalalignment, verticalalignment, ax)
#     888         if not isinstance(label, str):
#     889             label = str(label)  # this makes "1" and 1 labeled the same
# --> 890         t = ax.text(
#     891             x,
#     892             y,
#
# TypeError: text() missing 1 required positional argument: 's'

# %%
path_to_file = './Netwrk/EDI.nt2'

H = nx.Graph()

box = np.array([6.926, 6.926, 6.410])

with open(path_to_file) as f:
    line = ' '

    while line:
        line = f.readline()

        if line == 'Vertex table:\n':
            
            while line:

                line = f.readline()
                
                if line == '\n':
                    break
                else:
                    line_list = line.split()
                    key = int(line_list[0])
                    coord_x = float(line_list[1])
                    coord_y = float(line_list[2])
                    coord_z = float(line_list[3])
                    min_dist_atom = float(line_list[4])

                    H.add_node(key + x_1, coord=np.array([coord_x + box[0], coord_y, coord_z]), 
                               rad_max_sph=min_dist_atom, pagerank=1)
        
        elif line == 'Edge table:\n':
            while line:

                line = f.readline()
                if line == '':
                    break
                else:
                    line_list = line.split()
                    origin = int(line_list[0])
                    destination = int(line_list[2])
                    larger_radius = float(line_list[3])
                    x_sim = int(line_list[4])
                    y_sim = int(line_list[5])
                    z_sim = int(line_list[6])
                    if sum([abs(x_sim), abs(y_sim), abs(z_sim)]) == 0:
                        H.add_node(destination + x_1, coord=G.nodes[destination]['coord'] + 
                                   np.array([box[0], 0, 0]), rad_max_sph=G.nodes[destination]['rad_max_sph'])

    #                     G.add_edge(origin, destination + x_1, weight=larger_radius)
                        H.add_edge(origin + x_1, destination + x_1, rad_max_sph=larger_radius)
                    elif x_sim == -1:
                        pass
                    else:
                        pass

                    
                
                
                
#                 if sum([abs(x_sim), abs(y_sim), abs(z_sim)]) == 0:
#                     pass
#                     edge_table = edge_table.append({'origin':origin, 'destination': destination, 'x_sim':x_sim,
#                                                     'y_sim':y_sim, 'z_sim':z_sim,'larger_radius':larger_radius},
#                                                    ignore_index = True)
                    #print('change')

# %%
G.add_nodes_from(H.nodes)
G.add_edges_from(H.edges)

# %%
G[117][110]
# Out:
# {'rad_max_sph': 0.498201}

# %%
H.edges[edge[0], edge[1]]
# Out:
# {'rad_max_sph': 2.51601}

# %%
for node in H.nodes:
    for attr in H.nodes[node]:
        G.nodes[node][attr] = H.nodes[node][attr]
        
for edge in H.edges:
    for attr in H.edges[edge[0], edge[1]]:
        G.edges[edge][attr] = H.edges[edge][attr]

# %%
nx.draw(H, with_labels=True, font_weight='bold')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_27121/869137078.py in <module>
# ----> 1 nx.draw(H, with_labels=True, font_weight='bold')
#
# ~/anaconda3/lib/python3.8/site-packages/networkx/drawing/nx_pylab.py in draw(G, pos, ax, **kwds)
#     121         kwds["with_labels"] = "labels" in kwds
#     122
# --> 123     draw_networkx(G, pos=pos, ax=ax, **kwds)
#     124     ax.set_axis_off()
#     125     plt.draw_if_interactive()
#
# ~/anaconda3/lib/python3.8/site-packages/networkx/drawing/nx_pylab.py in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     336     draw_networkx_edges(G, pos, arrows=arrows, **edge_kwds)
#     337     if with_labels:
# --> 338         draw_networkx_labels(G, pos, **label_kwds)
#     339     plt.draw_if_interactive()
#     340
#
# ~/anaconda3/lib/python3.8/site-packages/networkx/drawing/nx_pylab.py in draw_networkx_labels(G, pos, labels, font_size, font_color, font_family, font_weight, alpha, bbox, horizontalalignment, verticalalignment, ax)
#     888         if not isinstance(label, str):
#     889             label = str(label)  # this makes "1" and 1 labeled the same
# --> 890         t = ax.text(
#     891             x,
#     892             y,
#
# TypeError: text() missing 1 required positional argument: 's'

# %%
# nx.maximum_flow(G, _s=0, _t=70, capacity='weight')[1]

# %%
neigh_dic = {}
for n, nbrs in G.adj.items():
    neigh = []
    for nbr, eattr in nbrs.items():
        neigh.append(nbr)
        
        
    neigh_dic[str(n)] = neigh

# %%
conexion['3']
edge_table.loc[edge_table['destination'] == '80']
# vertex_table.loc[vertex_table['key'] == '80']
# [3, 79, 132]
conexion['80']
# Out:
# {'3': 0.5}

# %%
def PageRank(graph, iteration, conexion, neigh_dic):
        for i in range(iteration):
            last = PageRank_one_iter(graph, conexion, neigh_dic)
        return(last)

def PageRank_one_iter(graph, conexion, neigh_dic):
    node_list = sorted(list(graph.nodes))
    for node in node_list:
        update_pagerank(node, conexion, neigh_dic, graph)
#         graph.normalize_pagerank()
    pagerank_list = np.asarray([graph.nodes[node]['pagerank'] for node in node_list], dtype='float32')
    return pagerank_list

def update_pagerank(selfnode, conexion, neigh_dic, graph):
    in_neighbors = neigh_dic[str(selfnode)] #self.parents
#     print(in_neighbors, selfnode)
    pagerank_sum = sum(graph.nodes[node]['pagerank']*conexion[str(selfnode)][str(node)]
                       for node in in_neighbors)
#     print(selfnode)
    graph.nodes[selfnode]['pagerank'] = pagerank_sum
    
    
info = PageRank(G, 25, conexion,neigh_dic)
np.argsort(info)
x = G.nodes[list(G.nodes)[16]]
G.nodes[list(G.nodes)[16]]
# Out:
# {'coord': array([3.463, 3.463, 3.205]),
#  'rad_max_sph': 2.65996,
#  'pagerank': 7.456862118963146}

# %%
info

# %%
                        vertex_table = vertex_table.append({
                            'coord_x':vertex_table.loc[vertex_table['key']  == str(destination), ['coord_x']].values[0][0] + box[0],                               
                            'coord_y':vertex_table.loc[vertex_table['key']  == str(destination),['coord_y']].values[0][0],                                 'coord_z':vertex_table.loc[vertex_table['key']  == str(destination), ['coord_z']].values[0][0],
                            'min_dist_atom':vertex_table.loc[vertex_table['key']  == str(int(destination),['min_dist_atom']].values[0][0],
                            'key':str(int(destination) + x_1)},ignore_index = True)
# Out:
# 1

# %%
# %matplotlib notebook
fig = plt.figure(figsize=(8,8))

ax = fig.add_subplot(111, projection='3d')

ax.scatter(x['coord'][0], x['coord'][1], x['coord'][2], s=20, c='black')

for node in G.nodes:
    if node > 69:
        ax.scatter(G.nodes[node]['coord'][0], G.nodes[node]['coord'][1], G.nodes[node]['coord'][2], s=19, c='red')
    else:
        ax.scatter(G.nodes[node]['coord'][0], G.nodes[node]['coord'][1], G.nodes[node]['coord'][2], s=1, c='green')
# Out:
# [autoreload of networkx.utils.random_sequence failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: powerlaw_sequence() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.classes.graphviews failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: reverse_view() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.classes.function failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: common_neighbors() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.convert_matrix failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: to_numpy_recarray() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.generators.classic failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: complete_graph() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.generators.cographs failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: random_cograph() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.generators.community failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: relaxed_caveman_graph() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.generators.degree_seq failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: configuration_model() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.generators.directed failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: gn_graph() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.generators.duplication failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: partial_duplication_graph() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.generators.geometric failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: random_geometric_graph() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.generators.internet_as_graphs failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: random_internet_as_graph() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.asteroidal failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: find_asteroidal_triple() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.bridges failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: bridges() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.chains failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: chain_decomposition() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.centrality.betweenness failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: betweenness_centrality() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.centrality.closeness failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: incremental_closeness_centrality() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.centrality.subgraph_alg failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: subgraph_centrality_exp() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.centrality.current_flow_closeness failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: current_flow_closeness_centrality() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.centrality.current_flow_betweenness failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: approximate_current_flow_betweenness_centrality() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.centrality.current_flow_betweenness_subset failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: current_flow_betweenness_centrality_subset() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.centrality.degree_alg failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: in_degree_centrality() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.centrality.eigenvector failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: eigenvector_centrality() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.centrality.group failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: group_in_degree_centrality() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.centrality.katz failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: katz_centrality() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.centrality.second_order failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: second_order_centrality() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.centrality.trophic failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: trophic_levels() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.components.connected failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: connected_components() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.components.strongly_connected failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: strongly_connected_components() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.components.weakly_connected failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: weakly_connected_components() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.components.attracting failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: attracting_components() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.components.biconnected failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: is_biconnected() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.components.semiconnected failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: is_semiconnected() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.chordal failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: complete_to_chordal_graph() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.cluster failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: triangles() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.clique failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: enumerate_all_cliques() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.communicability_alg failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: communicability() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.coloring.greedy_coloring failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: strategy_random_sequential() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.core failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: core_number() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.covering failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: min_edge_cover() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.cycles failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: cycle_basis() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.d_separation failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: d_separated() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.generators.trees failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: random_tree() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.dag failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: all_topological_sorts() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.distance_measures failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: resistance_distance() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.distance_regular failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: intersection_array() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.dominance failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: immediate_dominators() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.efficiency_measures failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: efficiency() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.euler failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: eulerize() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.link_analysis.pagerank_alg failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: pagerank() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.link_prediction failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: resource_allocation_index() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.lowest_common_ancestors failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: tree_all_pairs_lowest_common_ancestor() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.mis failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: maximal_independent_set() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.moral failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: moral_graph() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.non_randomness failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: non_randomness() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.operators.product failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: power() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.reciprocity failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: reciprocity() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.regular failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: is_k_regular() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.richclub failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: rich_club_coefficient() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.algorithms.simple_paths failed: Traceback (most recent call last):
# ...
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: stochastic_graph() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.readwrite.adjlist failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: write_adjlist() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.readwrite.multiline_adjlist failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: write_multiline_adjlist() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.readwrite.edgelist failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: write_edgelist() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.readwrite.gpickle failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: write_gpickle() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.readwrite.pajek failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: write_pajek() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.readwrite.leda failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: read_leda() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.readwrite.graph6 failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: read_graph6() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.readwrite.sparse6 failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: read_sparse6() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.readwrite.gml failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: read_gml() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.readwrite.graphml failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: write_graphml_xml() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.readwrite.gexf failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: write_gexf() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.readwrite.json_graph.jit failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: jit_data() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.linalg.laplacianmatrix failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: laplacian_matrix() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.linalg.algebraicconnectivity failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: algebraic_connectivity() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.linalg.modularitymatrix failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: modularity_matrix() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.linalg.bethehessianmatrix failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: bethe_hessian_matrix() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.drawing.layout failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: random_layout() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.drawing.nx_agraph failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: view_pygraphviz() requires a code object with 5 free vars, not 0
# ]
# [autoreload of networkx.drawing.nx_pydot failed: Traceback (most recent call last):
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/lucasperea/anaconda3/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: write_dot() requires a code object with 5 free vars, not 0
# ]
# <img src="data:image/png;base64,..." width="799.5">
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_27121/1626308882.py in <module>
#       4 ax = fig.add_subplot(111, projection='3d')
#       5
# ----> 6 ax.scatter(x['coord'][0], x['coord'][1], x['coord'][2], s=20, c='black')
#       7
#       8 for node in G.nodes:
#
# TypeError: 'NoneType' object is not subscriptable

# %%
dir(G)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_adj',
#  '_node',
#  'add_edge',
#  'add_edges_from',
#  'add_node',
#  'add_nodes_from',
#  'add_weighted_edges_from',
#  'adj',
#  'adjacency',
#  'adjlist_inner_dict_factory',
#  'adjlist_outer_dict_factory',
#  'clear',
#  'clear_edges',
#  'copy',
#  'degree',
#  'edge_attr_dict_factory',
#  'edge_subgraph',
#  'edges',
#  'get_edge_data',
#  'graph',
#  'graph_attr_dict_factory',
#  'has_edge',
#  'has_node',
#  'is_directed',
#  'is_multigraph',
#  'name',
#  'nbunch_iter',
#  'neighbors',
#  'node_attr_dict_factory',
#  'node_dict_factory',
#  'nodes',
#  'number_of_edges',
#  'number_of_nodes',
#  'order',
#  'remove_edge',
#  'remove_edges_from',
#  'remove_node',
#  'remove_nodes_from',
#  'size',
#  'subgraph',
#  'to_directed',
#  'to_directed_class',
#  'to_undirected',
#  'to_undirected_class',
#  'update']

# %%
G.copy.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_27121/3398221172.py in <module>
# ----> 1 G.copy.deepcopy()
#
# AttributeError: 'function' object has no attribute 'deepcopy'

# %%
L = copy.deepcopy(G)

# %%
L.nodes[0]
# Out:
# {'coord': array([3.31303, 3.463  , 2.62059]),
#  'rad_max_sph': 2.09316,
#  'pagerank': 2.9429912127346767}
